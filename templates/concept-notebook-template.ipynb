# %% [markdown]
# # CONCEPT NOTEBOOK TEMPLATE
#
# **Unit:** [Unit ID] — [Unit Title]
#
# **Phase:** [Phase Name]
#
# **Status:** DRAFT / VERIFIED / BLOCKED
#
# ---
#
# ## 1. What Are We Solving?
#
# [Describe the problem this concept addresses.]
#
# ## 2. Why Does This Matter?
#
# [Explain why this concept is important and where it's used.]
#
# ## 3. Prerequisites
#
# - [Prerequisite 1]
# - [Prerequisite 2]
#
# ## 4. Learning Objectives
#
# By the end of this notebook, you should be able to:
# - [Objective 1]
# - [Objective 2]
#
# ## 5. Mental Model
#
# [Describe the mental model — what should you visualize/understand?]

# %% [markdown]
# ## 6. Mathematical Foundation
#
# [Explain the mathematics that makes this concept work. Use LaTeX where helpful.]
#
# $$[equation]$$

# %% [markdown]
# ## 7. Small Intuitive Example
#
# [A tiny, concrete example that builds intuition before the real implementation.]

# %%
# Small intuitive example
# [code]

# %% [markdown]
# ## 8. First Implementation
#
# [Implement the concept from scratch.]

# %%
# First implementation
# [code]

# %% [markdown]
# ## 9. Inspect the Implementation
#
# [Examine what the implementation does. Print intermediate values, visualize, explain.]

# %%
# Inspect
# [code]

# %% [markdown]
# ## 10. Experiment
#
# [Change something and observe the effect.]

# %%
# Experiment
# [code]

# %% [markdown]
# ## 11. Visualization
#
# [Visualize the concept to build intuition.]

# %%
# Visualization
# [code]

# %% [markdown]
# ## 12. Failure Case
#
# [Show a controlled example of what goes wrong.]

# %%
# Failure case
# [code]

# %% [markdown]
# ## 13. Debugging
#
# [Explain how to detect and fix the failure.]

# %% [markdown]
# ## 14. Alternative Implementation
#
# [Show a different way to implement the same concept.]

# %%
# Alternative implementation
# [code]

# %% [markdown]
# ## 15. Library Implementation
#
# [Use a mature library to implement the same concept.]

# %%
# Library implementation
# [code]

# %% [markdown]
# ## 16. Compare Implementations
#
# [Compare the from-scratch and library implementations. What's the same? What's different?]

# %% [markdown]
# ## 17. Evaluation
#
# [How do we measure whether this works?]

# %%
# Evaluation
# [code]

# %% [markdown]
# ## 18. Real-World Considerations
#
# [What matters in production? Latency, cost, scale, robustness?]

# %% [markdown]
# ## 19. Common Mistakes
#
# - [Mistake 1]
# - [Mistake 2]

# %% [markdown]
# ## 20. When NOT to Use It
#
# [When should this concept be avoided?]

# %% [markdown]
# ## 21. Challenge
#
# [A challenge to test understanding.]

# %%
# Challenge
# [code]

# %% [markdown]
# ## 22. Closed-Book Recall
#
# Without looking back, answer:
#
# 1. Explain the concept.
# 2. Write the key equation.
# 3. Explain the algorithm.
# 4. Explain one failure case.
# 5. Explain when to use it.

# %% [markdown]
# ## 23. Teach-Back Questions
#
# Explain this concept to another person. What questions would they ask?
#
# - [Question 1]
# - [Question 2]

# %% [markdown]
# ## 24. Summary
#
# [Summarize the key takeaways.]

# %% [markdown]
# ## 25. Further Experiment
#
# [What should you try next to deepen understanding?]

# %% [markdown]
# ---
#
# ## Verification Status
#
# ```
# STATUS: [VERIFIED / BLOCKED]
# EXECUTION: [PASS / FAIL / N/A]
# DEPENDENCIES: [PASS / FAIL]
# OUTPUTS: [PASS / FAIL]
# LAST VERIFIED: [YYYY-MM-DD]
# ```
