# %% [markdown]
# # IMPLEMENTATION NOTEBOOK TEMPLATE
#
# **Unit:** [Unit ID] — [Unit Title]
#
# **Phase:** [Phase Name]
#
# **Status:** DRAFT / VERIFIED / BLOCKED
#
# ---
#
# ## 1. What Are We Building?
#
# [Describe the implementation.]
#
# ## 2. Why Does This Matter?
#
# [Explain why this implementation is important.]
#
# ## 3. Prerequisites
#
# - [Prerequisite 1]
# - [Prerequisite 2]
#
# ## 4. Learning Objectives
#
# By the end of this notebook, you should be able to:
# - [Objective 1]
# - [Objective 2]
#
# ## 5. Setup
#
# [Import libraries, set seeds, configure.]

# %%
# Setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Deterministic seeds
np.random.seed(42)

# Display settings
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## 6. Data
#
# [Load or create the data. Explain its structure.]

# %%
# Load data
# [code]

# %% [markdown]
# ## 7. Implementation
#
# [Implement the core functionality.]

# %%
# Implementation
# [code]

# %% [markdown]
# ## 8. Test the Implementation
#
# [Verify the implementation works correctly.]

# %%
# Test
# [code]

# %% [markdown]
# ## 9. Experiment
#
# [Change parameters and observe effects.]

# %%
# Experiment
# [code]

# %% [markdown]
# ## 10. Visualization
#
# [Visualize the results.]

# %%
# Visualization
# [code]

# %% [markdown]
# ## 11. Evaluation
#
# [Evaluate the implementation with appropriate metrics.]

# %%
# Evaluation
# [code]

# %% [markdown]
# ## 12. Failure Case
#
# [Show what goes wrong and how to fix it.]

# %%
# Failure case
# [code]

# %% [markdown]
# ## 13. Real-World Considerations
#
# [What matters in production?]

# %% [markdown]
# ## 14. Common Mistakes
#
# - [Mistake 1]
# - [Mistake 2]

# %% [markdown]
# ## 15. Challenge
#
# [A challenge to test understanding.]

# %%
# Challenge
# [code]

# %% [markdown]
# ## 16. Closed-Book Recall
#
# Without looking back:
#
# 1. Explain the implementation.
# 2. Write the key equation.
# 3. Explain the algorithm.
# 4. Explain one failure case.
# 5. Explain when to use it.

# %% [markdown]
# ## 17. Summary
#
# [Summarize the key takeaways.]

# %% [markdown]
# ---
#
# ## Verification Status
#
# ```
# STATUS: [VERIFIED / BLOCKED]
# EXECUTION: [PASS / FAIL / N/A]
# DEPENDENCIES: [PASS / FAIL]
# OUTPUTS: [PASS / FAIL]
# LAST VERIFIED: [YYYY-MM-DD]
# ```
