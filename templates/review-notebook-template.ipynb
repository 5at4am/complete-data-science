# %% [markdown]
# # REVIEW NOTEBOOK TEMPLATE
#
# **Units Reviewed:** [Unit IDs]
#
# **Phase:** [Phase Name]
#
# **Status:** DRAFT / VERIFIED / BLOCKED
#
# ---
#
# ## 1. Retrieval Questions
#
# Answer these WITHOUT looking back at the original notebooks.
#
# ### Question 1
#
# [Question]
#
# **Your answer:**
#
# ### Question 2
#
# [Question]
#
# **Your answer:**
#
# ### Question 3
#
# [Question]
#
# **Your answer:**

# %% [markdown]
# ## 2. Implementation Challenge
#
# [Rebuild a key implementation from scratch, without looking.]

# %%
# Implementation challenge
# [code]

# %% [markdown]
# ## 3. Debugging Challenge
#
# [A buggy implementation. Find and fix the bug.]

# %%
# Debugging challenge
# [buggy code]

# %% [markdown]
# ## 4. Comparison Questions
#
# [Compare two approaches. When would you use each?]

# %% [markdown]
# ## 5. Teach-Back
#
# [Explain a concept to another person. Write it out.]

# %% [markdown]
# ## 6. Mini Project
#
# [A small project that combines the reviewed concepts.]

# %%
# Mini project
# [code]

# %% [markdown]
# ## 7. Cumulative Experiment
#
# [An experiment that reuses concepts from multiple units.]

# %%
# Cumulative experiment
# [code]

# %% [markdown]
# ## 8. Self-Assessment
#
# Rate your mastery of each reviewed unit (0-6):
#
# | Unit | Mastery | Notes |
# |------|---------|-------|
# | [Unit] | | |
#
# ## 9. Weak Areas
#
# [What did you struggle with? What needs more review?]

# %% [markdown]
# ---
#
# ## Verification Status
#
# ```
# STATUS: [VERIFIED / BLOCKED]
# EXECUTION: [PASS / FAIL / N/A]
# DEPENDENCIES: [PASS / FAIL]
# OUTPUTS: [PASS / FAIL]
# LAST VERIFIED: [YYYY-MM-DD]
# ```
